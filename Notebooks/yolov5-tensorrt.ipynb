# %%
import os
os.chdir('/nfs/homedirs/rachwan/Torch-Pruning/examples/yolo_example/yolov5')
import torch
import numpy as np

# %%
checkpoint = torch.load('/nfs/homedirs/rachwan/Torch-Pruning/examples/yolo_example/yolov5/runs/train/exp634/weights/best.pt')
model = checkpoint['model'].cuda()
model.float()
model

# %%
import export
model.cuda()
export.run(model=model, device=0, half=True, batch_size=1)

# %%
# !python export.py --weights 'yolov5s.pt' --device 0 --half --batch-size=1 --include engine

# %%
from models.common import DetectMultiBackend
model = DetectMultiBackend('/nfs/homedirs/rachwan/Torch-Pruning/examples/yolo_example/yolov5/runs/train/exp634/weights/best.pt', device='cuda', dnn=False, data='data/coco.yaml', fp16=True)
model
# Out:
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients
# DetectMultiBackend(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): C3(
#         (cv1): Conv(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): Bottleneck(
#             (cv1): Conv(
# ...

# %%
from evaluation_tool.models.metrics.Evaluator import Evaluator
evaluator = Evaluator()

evaluator.evaluate_inference(model, tuple([3, 640, 640]), 'cuda', iterations=100, batch_size=64, half=True)

evaluator.get_all_metrics()
# Out:
# {'time': 25.063447265625,
#  'gpu': 4.408118784,
#  'disk': 10018.030434,
#  'cost': 5709.66,
#  'emission': 0.0}

# %%
# !python val.py --weights '/nfs/homedirs/rachwan/Torch-Pruning/examples/yolo_example/yolov5/runs/train/exp283/weights/best.pt' --data coco.yaml --img 640 --task speed

# %%
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --task speed
