# %%
import os
os.chdir('/nfs/homedirs/rachwan/Torch-Pruning/examples/nyu_depth/P3Depth/')

# %%
# !python -u trainer.py --model_config configs/models/StructRankNetPQRS_res101.yaml --dataset_config configs/datasets/NYU_Depth_v2.yaml --exp_config experiments/configs/exp1.yaml

# %%
# !python /nfs/homedirs/rachwan/Torch-Pruning/examples/yolo_example/yolov5/train_pruning_global.py --data coco.yaml --cfg yolov5s.yaml --weights 'yolov5s.pt' --batch-size 64 --epochs 30 --amount 0.7 --cos-lr
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train_pruning_global: weights=yolov5s.pt, cfg=yolov5s.yaml, data=coco.yaml, hyp=../../yolo_example/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=64, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=../../yolo_example/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=True, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, amount=0.7, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# ...
