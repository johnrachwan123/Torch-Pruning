# %%
import os
os.chdir('/nfs/homedirs/rachwan/Torch-Pruning')
import torch
import numpy as np

# %%
import mlflow
os.chdir('/nfs/homedirs/rachwan/Torch-Pruning/examples/yolo_example/yolov5')
from models.yolo import Model

# %%
os.chdir('/nfs/homedirs/rachwan/Torch-Pruning')
mlflow.set_tracking_uri("sqlite:///sustainablecatalog.db")

# %%
reg_model_name = "yolov5-coco-prunedl2m-torch"

# %%
model_uri = f"models:/{reg_model_name}/1"
loaded_model = mlflow.sklearn.load_model(model_uri).float()

# %%
loaded_model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 31, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(31, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(31, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (3): Conv(
#       (conv): Conv2d(64, 124, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(124, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (4): C3(
#       (cv1): Conv(
#         (conv): Conv2d(124, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(124, 63, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(63, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(127, 121, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(121, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Conv(
#       (conv): Conv2d(121, 188, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(188, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (6): C3(
#       (cv1): Conv(
#         (conv): Conv2d(188, 127, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(127, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(188, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(122, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(249, 186, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(186, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(127, 106, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(106, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(106, 127, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(127, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (1): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(127, 110, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(110, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(110, 127, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(127, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#         (2): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(127, 113, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(113, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(113, 127, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(127, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (7): Conv(
#       (conv): Conv2d(186, 207, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(207, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (8): C3(
#       (cv1): Conv(
#         (conv): Conv2d(207, 190, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(190, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(207, 92, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(92, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(282, 242, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(242, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(190, 109, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(109, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(109, 190, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(190, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (9): SPPF(
#       (cv1): Conv(
#         (conv): Conv2d(242, 71, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(71, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(284, 213, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(213, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (10): Conv(
#       (conv): Conv2d(213, 59, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(59, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (11): Upsample(scale_factor=2.0, mode=nearest)
#     (12): Concat()
#     (13): C3(
#       (cv1): Conv(
#         (conv): Conv2d(245, 93, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(93, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(245, 77, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(77, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(159, 149, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(149, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(93, 90, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(90, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(90, 82, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(82, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (14): Conv(
#       (conv): Conv2d(149, 62, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(62, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (15): Upsample(scale_factor=2.0, mode=nearest)
#     (16): Concat()
#     (17): C3(
#       (cv1): Conv(
#         (conv): Conv2d(183, 57, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(57, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(183, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(92, 83, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(83, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(57, 63, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(63, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(63, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(60, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (18): Conv(
#       (conv): Conv2d(83, 13, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(13, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (19): Concat()
#     (20): C3(
#       (cv1): Conv(
#         (conv): Conv2d(75, 52, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(52, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(75, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(75, 73, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(73, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(52, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(56, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(56, 59, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(59, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (21): Conv(
#       (conv): Conv2d(73, 2, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(2, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (22): Concat()
#     (23): C3(
#       (cv1): Conv(
#         (conv): Conv2d(61, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(3, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(61, 7, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(7, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv3): Conv(
#         (conv): Conv2d(27, 90, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(90, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): Sequential(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(3, 5, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(5, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(5, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(20, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (24): Detect(
#       (m): ModuleList(
#         (0): Conv2d(83, 255, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(73, 255, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(90, 255, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#   )
# )

# %%
from evaluation_tool.models.metrics.Evaluator import Evaluator
evaluator = Evaluator()

evaluator.evaluate_inference(loaded_model, tuple([3, 640, 640]), 'cuda', iterations=100, batch_size=1)

evaluator.get_all_metrics()
# Out:
# {'time': 22.8337939453125,
#  'gpu': 0.047398912,
#  'disk': 69.60702599999999,
#  'cost': 5201.259999999999,
#  'emission': 0.029194146582096386,
#  'energy': 0.09699052020630028}
